# %%
import numpy as np
import matplotlib.pyplot as plt

def init_weights(shape):
    return np.random.uniform(-1, 1, shape)

shape = (10, 10)
weights = init_weights(shape)

plt.imshow(weights, cmap='viridis')
plt.colorbar()
plt.title('Representación visual de la matriz de pesos')
plt.show()

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.datasets.fashion_mnist import load_data

# Cargar datos
(X_train, y_train), (X_test, y_test) = load_data()

# Preprocesamiento
X_train = X_train.reshape((-1, 28, 28, 1)) / 255.0
X_test = X_test.reshape((-1, 28, 28, 1)) / 255.0

# Parámetros
batch_size = 8
n_epochs = 20
learn_rate = 0.0001

# Modelo CNN
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(28, 28, 1)),
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

# Compilar y entrenar
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learn_rate),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, batch_size=batch_size, epochs=n_epochs)

# Evaluar
loss, accuracy = model.evaluate(X_test, y_test)
print('Loss:', loss)
print('Accuracy:', accuracy)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 7s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/20
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 36s 4ms/step - accuracy: 0.6943 - loss: 0.9151
# Epoch 2/20
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - accuracy: 0.8425 - loss: 0.4497
# Epoch 3/20
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - accuracy: 0.8616 - loss: 0.3935
# Epoch 4/20
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - accuracy: 0.8736 - loss: 0.3582
# Epoch 5/20
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - accuracy: 0.8828 - loss: 0.3353
# Epoch 6/20
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - accuracy: 0.8843 - loss: 0.3237
# Epoch 7/20
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - accuracy: 0.8906 - loss: 0.3059
# Epoch 8/20
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - accuracy: 0.8928 - loss: 0.2969
# Epoch 9/20
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 29s 4ms/step - accuracy: 0.8958 - loss: 0.2887
# Epoch 10/20
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - accuracy: 0.9021 - loss: 0.2766
# Epoch 11/20
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - accuracy: 0.9019 - loss: 0.2681
# Epoch 12/20
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - accuracy: 0.9062 - loss: 0.2615
# Epoch 13/20
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - accuracy: 0.9083 - loss: 0.2556
# Epoch 14/20
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - accuracy: 0.9094 - loss: 0.2530
# Epoch 15/20
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - accuracy: 0.9088 - loss: 0.2502
# Epoch 16/20
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 29s 4ms/step - accuracy: 0.9164 - loss: 0.2341
# Epoch 17/20
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 29s 4ms/step - accuracy: 0.9185 - loss: 0.2299
# Epoch 18/20
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - accuracy: 0.9167 - loss: 0.2299
# Epoch 19/20
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - accuracy: 0.9193 - loss: 0.2229
# Epoch 20/20
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 69s 9ms/step - accuracy: 0.9226 - loss: 0.2159
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9011 - loss: 0.2849
# Loss: 0.2766430079936981
# Accuracy: 0.8996999859809875
